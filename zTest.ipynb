# %%
import numpy as np
from scipy.stats import norm

# %%
sample=[172,174,168,171,173,175,170,169,172] #lets for example taking the dataset less than 30 values 
population_mean=170
population_std=3
sample_mean=np.mean(sample)
sample_size=len(sample)

# %%
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(sample_size))
z_score
# Out:
# np.float64(1.555555555555543)

# %%
#now lets find the p_value
p_value=2*(1-norm.cdf(abs(z_score)))
p_value
print("Z-score:", z_score)
print("P-value:", p_value)
